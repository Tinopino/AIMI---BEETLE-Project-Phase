# %% [markdown]
# # EASY TRAINER LOADING
# ---
# Note that this is different from loading a predictor (for inference)

# %%
# !pip3 install -e /data/pathology/projects/pathology-lung-TIL/nnUNet_v2

# %% [markdown]
# # Libraries and utils

# %%
import os
import numpy as np
import torch
from nnunetv2.run.run_training import get_trainer_from_args
from nnunetv2.experiment_planning.experiment_planners.pathology_experiment_planner import PathologyExperimentPlanner
from nnunetv2 import paths as nnunetv2_paths

# %% [markdown]
# # Set variables

# %%
sorted(os.listdir(nnunetv2_paths.nnUNet_preprocessed))
# Out:
# ['Dataset004_TIGER_split',
#  'Dataset005_PDL1_test',
#  'Dataset006_pseudo_labeling_test',
#  'Dataset007_PDL1_simplified_annotations',
#  'Dataset008_PDL1_simplified_and_union_annotations',
#  'Dataset009_pseudo_labeling_test2',
#  'Dataset010_pseudo_labeling_test3',
#  'Dataset011_pseudo_labeling_test4_json_spacing8',
#  'Dataset012_pseudo_labeling_test4_json_spacing4',
#  'Dataset013_pseudo_labeling_test4_json_sapcing2',
#  'Dataset015_PDL1_simplified_trainset_only',
#  'temp_old_Dataset004_TIGER_split']

# %% [markdown]
# ### Set these

# %%
dataset_name_or_id = '8'
fold = 0
trainer_class_name = 'nnUNetTrainer_WSD_wei_i0_nnunet_aug'

# %% [markdown]
# ### Default settings

# %%
configuration = '2d'
plans_identifier = 'nnUNetWholeSlideDataPlans'
use_compressed_data = False
device = torch.device('cuda')

# %% [markdown]
# # Experiment planning

# %%
gpu = PathologyExperimentPlanner.get_gpu_size()
gpu = 11
planner = PathologyExperimentPlanner(dataset_name_or_id, gpu)
plans = planner.plan_experiment()
# Out:
# GPU Memory Size: 12.00 GB
# fullres_spacing_transposed[1:] [1, 1]
# new_median_shape_transposed[1:] [1024, 1024]
# self.generate_data_identifier(2d) nnUNetWholeSlideDataPlans_2d
# approximate_n_voxels_dataset None
# [1024 1024]
# square [896, 896]
# [896 896]
# square [768, 768]
# [768 768]
# square [640, 640]
# [640 640]
# square [512, 512]
# 2D U-Net configuration:
# {'data_identifier': 'nnUNetWholeSlideDataPlans_2d', 'preprocessor_name': 'DefaultPreprocessor', 'batch_size': 17, 'patch_size': array([512, 512]), 'median_image_size_in_voxels': [1024, 1024], 'spacing': [1, 1], 'normalization_schemes': ['RGBTo01Normalization', 'RGBTo01Normalization', 'RGBTo01Normalization'], 'use_mask_for_norm': [False, False, False], 'UNet_class_name': 'PlainConvUNet', 'UNet_base_num_features': 32, 'n_conv_per_stage_encoder': (2, 2, 2, 2, 2, 2, 2, 2), 'n_conv_per_stage_decoder': (2, 2, 2, 2, 2, 2, 2), 'num_pool_per_axis': [7, 7], 'pool_op_kernel_sizes': [[1, 1], [2, 2], [2, 2], [2, 2], [2, 2], [2, 2], [2, 2], [2, 2]], 'conv_kernel_sizes': [[3, 3], [3, 3], [3, 3], [3, 3], [3, 3], [3, 3], [3, 3], [3, 3]], 'unet_max_num_features': 512, 'batch_dice': True}
# Plans were saved to /data/pathology/projects/nnUNet_v2/joey/data/nnUNet_preprocessed/Dataset008_PDL1_simplified_and_union_annotations/nnUNetWholeSlideDataPlans.json
# [DONE PLANNING]

# %% [markdown]
# # Get trainer

# %%
# !pip3 install -e /data/pathology/projects/pathology-lung-TIL/nnUNet_v2
nnunet_trainer = get_trainer_from_args(dataset_name_or_id, 
                                       configuration, 
                                       fold, 
                                       trainer_class_name, 
                                       plans_identifier, 
                                       use_compressed_data, 
                                       device=device)
# Out:
# Using device: cuda:0
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################

# %%
tr_dl, val_dl = nnunet_trainer.get_dataloaders(subset=True, cpus=10)
# Out:
# USING DATA SUBSET
#
#
#
#
# Found splits.json
# [Getting WSD dataloaders]
# [ITERATOR TEMPLATE] Using iterator template: /data/pathology/projects/nnUNet_v2/nnUNet_v2_rework_merge/nnunetv2/training/nnUNetTrainer/variants/pathology/wsd_weighted_iterator_nnunet_aug_template.json
# Still timing everything, only copying SOME training and val files
# [LABEL SAMPLE WEIGHTS]
# {'pd-l1+ tumor': 0.334, 'pd-l1- tumor': 0.333, 'unknown': 0.333}
#
#
#
# TEMP BATCH SIZE 8
#
#
#
# Taking random seed 697 for iterators
# cpus used for iterators =  10
# [Creating batch iterators]
# 	[Creating TRAIN batch iterator]
# | Copied '/data/pathology/archives/lung/immunotherapy_pilot/all_images/LI_S01_P000007_C0041_L01_A01.tif' | To: '/home/user/images/LI_S01_P000007_C0041_L01_A01.tif'
# .
# | Copied '/data/pathology/archives/lung/immunotherapy_pilot/annotations/pdl1_segmentation/xml_simplify_and_union/LI_S01_P000007_C0041_L01_A01.xml' | To: '/home/user/annotations/LI_S01_P000007_C0041_L01_A01.xml'
# .
# | Copied '/data/pathology/archives/lung/pdl1_verona/dearrayed_dataset/GC2_1413061_core0.tif' | To: '/home/user/images/GC2_1413061_core0.tif'
# .
# | Copied '/data/pathology/archives/lung/immunotherapy_pilot/annotations/pdl1_segmentation/xml_simplify_and_union/GC2_1413061_core0.xml' | To: '/home/user/annotations/GC2_1413061_core0.xml'
# .
# | Copied '/data/pathology/archives/lung/immunotherapy_pilot/all_images/LI_S01_P000037_C0041_L01_A01.tif' | To: '/home/user/images/LI_S01_P000037_C0041_L01_A01.tif'
# .
# | Copied '/data/pathology/archives/lung/immunotherapy_pilot/annotations/pdl1_segmentation/xml_simplify_and_union/LI_S01_P000037_C0041_L01_A01.xml' | To: '/home/user/annotations/LI_S01_P000037_C0041_L01_A01.xml'
# .
# | Copied '/data/pathology/archives/lung/pdl1_verona/dearrayed_dataset/AK1_402504_core0.tif' | To: '/home/user/images/AK1_402504_core0.tif'
# .
# | Copied '/data/pathology/archives/lung/immunotherapy_pilot/annotations/pdl1_segmentation/xml_simplify_and_union/AK1_402504_core0.xml' | To: '/home/user/annotations/AK1_402504_core0.xml'
# .
# | Copied '/data/pathology/archives/lung/pdl1_verona/dearrayed_dataset/GC2_1121818_core1.tif' | To: '/home/user/images/GC2_1121818_core1.tif'
# .
# | Copied '/data/pathology/archives/lung/immunotherapy_pilot/annotations/pdl1_segmentation/xml_simplify_and_union/GC2_1121818_core1.xml' | To: '/home/user/annotations/GC2_1121818_core1.xml'
# .
# | Copied '/data/pathology/archives/lung/pdl1_verona/dearrayed_dataset/PD-L1 AK7_619159_core3.tif' | To: '/home/user/images/PD-L1 AK7_619159_core3.tif'
# .
# | Copied '/data/pathology/archives/lung/immunotherapy_pilot/annotations/pdl1_segmentation/xml_simplify_and_union/PD-L1 AK7_619159_core3.xml' | To: '/home/user/annotations/PD-L1 AK7_619159_core3.xml'
# .
# | Copied '/data/pathology/archives/lung/pdl1_verona/dearrayed_dataset/AK1_402504_core3.tif' | To: '/home/user/images/AK1_402504_core3.tif'
# .
# | Copied '/data/pathology/archives/lung/immunotherapy_pilot/annotations/pdl1_segmentation/xml_simplify_and_union/AK1_402504_core3.xml' | To: '/home/user/annotations/AK1_402504_core3.xml'
# .
# | Copied '/data/pathology/archives/lung/pdl1_verona/dearrayed_dataset/AK1_521137_core3.tif' | To: '/home/user/images/AK1_521137_core3.tif'
# .
# | Copied '/data/pathology/archives/lung/immunotherapy_pilot/annotations/pdl1_segmentation/xml_simplify_and_union/AK1_521137_core3.xml' | To: '/home/user/annotations/AK1_521137_core3.xml'
# .
# | Copied '/data/pathology/archives/lung/pdl1_verona/dearrayed_dataset/AK1_501505_core2.tif' | To: '/home/user/images/AK1_501505_core2.tif'
# .
# | Copied '/data/pathology/archives/lung/immunotherapy_pilot/annotations/pdl1_segmentation/xml_simplify_and_union/AK1_501505_core2.xml' | To: '/home/user/annotations/AK1_501505_core2.xml'
# .
# | Copied '/data/pathology/archives/lung/pdl1_verona/dearrayed_dataset/PD-L1 AK4_1413310_core1.tif' | To: '/home/user/images/PD-L1 AK4_1413310_core1.tif'
# .
# | Copied '/data/pathology/archives/lung/immunotherapy_pilot/annotations/pdl1_segmentation/xml_simplify_and_union/PD-L1 AK4_1413310_core1.xml' | To: '/home/user/annotations/PD-L1 AK4_1413310_core1.xml'
# .
# 	[Creating VAL batch iterator]
# | Copied '/data/pathology/archives/lung/pdl1_verona/dearrayed_dataset/GC2_1305972_core3.tif' | To: '/home/user/images/GC2_1305972_core3.tif'
# .
# | Copied '/data/pathology/archives/lung/immunotherapy_pilot/annotations/pdl1_segmentation/xml_simplify_and_union/GC2_1305972_core3.xml' | To: '/home/user/annotations/GC2_1305972_core3.xml'
# .
# | Copied '/data/pathology/archives/lung/immunotherapy_pilot/all_images/LI_S01_P000009_C0041_L01_A01.tif' | To: '/home/user/images/LI_S01_P000009_C0041_L01_A01.tif'
# .
# | Copied '/data/pathology/archives/lung/immunotherapy_pilot/annotations/pdl1_segmentation/xml_simplify_and_union/LI_S01_P000009_C0041_L01_A01.xml' | To: '/home/user/annotations/LI_S01_P000009_C0041_L01_A01.xml'
# .
# | Copied '/data/pathology/archives/lung/pdl1_verona/dearrayed_dataset/AK1_501505_core1.tif' | To: '/home/user/images/AK1_501505_core1.tif'
# .
# | Copied '/data/pathology/archives/lung/immunotherapy_pilot/annotations/pdl1_segmentation/xml_simplify_and_union/AK1_501505_core1.xml' | To: '/home/user/annotations/AK1_501505_core1.xml'
# .
# | Copied '/data/pathology/archives/lung/pdl1_verona/dearrayed_dataset/GC2_1411374_core1.tif' | To: '/home/user/images/GC2_1411374_core1.tif'
# .
# | Copied '/data/pathology/archives/lung/immunotherapy_pilot/annotations/pdl1_segmentation/xml_simplify_and_union/GC2_1411374_core1.xml' | To: '/home/user/annotations/GC2_1411374_core1.xml'
# .
# | Copied '/data/pathology/archives/lung/pdl1_verona/dearrayed_dataset/AK1_521137_core2.tif' | To: '/home/user/images/AK1_521137_core2.tif'
# .
# | Copied '/data/pathology/archives/lung/immunotherapy_pilot/annotations/pdl1_segmentation/xml_simplify_and_union/AK1_521137_core2.xml' | To: '/home/user/annotations/AK1_521137_core2.xml'
# .
# [Returning batch iterators]

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from matplotlib import cm
# import pylab as plt

original_colormap = [ [ 0, 0, 0, 0 ], [ 0, 224, 249, 255 ], [ 0, 249, 50, 255 ], [ 174, 249, 0, 255 ], [ 249, 100, 0, 255 ], [ 249, 0, 125, 255 ], [ 149, 0, 249, 255 ], [ 0, 0, 206, 255 ], [ 0, 185, 206, 255 ], [ 0, 206, 41, 255 ], [ 143, 206, 0, 255 ], [ 206, 82, 0, 255 ], [ 206, 0, 103, 255 ], [ 124, 0, 206, 255 ], [ 0, 0, 162, 255 ], [ 0, 145, 162, 255 ], [ 0, 162, 32, 255 ], [ 114, 162, 0, 255 ], [ 162, 65, 0, 255 ], [ 162, 0, 81, 255 ], [ 97, 0, 162, 255 ], [ 0, 0, 119, 255 ], [ 0, 107, 119, 255 ], [ 0, 119, 23, 255 ], [ 83, 119, 0, 255 ], [ 119, 47, 0, 255 ], [ 119, 0, 59, 255 ], [ 71, 0, 119, 255 ], [ 100, 100, 249, 255 ], [ 100, 234, 249, 255 ], [ 100, 249, 129, 255 ], [ 204, 249, 100, 255 ], [ 249, 159, 100, 255 ], [ 249, 100, 174, 255 ], [ 189, 100, 249, 255 ], [ 82, 82, 206, 255 ], [ 82, 193, 206, 255 ], [ 82, 206, 107, 255 ], [ 168, 206, 82, 255 ], [ 206, 131, 82, 255 ], [ 206, 82, 143, 255 ], [ 156, 82, 206, 255 ], [ 65, 65, 162, 
, 249, 255 ], [ 0, 224, 249, 255 ], [ 0, 249, 50, 255 ], [ 174, 249, 0, 255 ], [ 249, 100, 0, 255 ], [ 249, 0, 125, 255 ], [ 149, 0, 249, 255 ], [ 0, 0, 206, 255 ], [ 0, 185, 206, 255 ], [ 0, 206, 41, 255 ], [ 143, 206, 0, 255 ], [ 206, 82, 0, 255 ], [ 206, 0, 103, 255 ], [ 124, 0, 206, 255 ], [ 0, 0, 162, 255 ], [ 0, 145, 162, 255 ], [ 0, 162, 32, 255 ], [ 114, 162, 0, 255 ], [ 162, 65, 0, 255 ], [ 162, 0, 81, 255 ], [ 97, 0, 162, 255 ], [ 0, 0, 119, 255 ], [ 0, 107, 119, 255 ], [ 0, 119, 23, 255 ], [ 83, 119, 0, 255 ], [ 119, 47, 0, 255 ], [ 119, 0, 59, 255 ], [ 71, 0, 119, 255 ], [ 100, 100, 249, 255 ], [ 100, 234, 249, 255 ], [ 100, 249, 129, 255 ], [ 0, 249, 50, 255 ] ]
colormap = np.array(original_colormap)/255.
cmap = LinearSegmentedColormap.from_list('my_cmap', colors=colormap)

label_names = ['None', 'Background', 'PD-L1- tumor', 'PD-L1+ tumor', 'Other']
# label_names = ['None', 'PD-L1- tumor', 'PD-L1+ tumor', 'PD-L1- immune', 'PD-L1+ immune', 'Other cells', 'Unknown']
label_index = list(range(len(label_names)))
n_labels = len(label_names)
label_plot_args = {"cmap":cmap, "vmin":0, "vmax":255, "interpolation":"none"}


# %matplotlib inline

# easy to copy paste in figures this way
fig, axs = plt.subplots(1, 2, figsize=(5, 5))
axs[-1].imshow([[i] for i in list(range(n_labels))], **label_plot_args)
axs[-1].set_yticks(label_index)
axs[-1].set_yticklabels(label_names)
axs[-1].yaxis.tick_right()
axs[-1].get_xaxis().set_visible(False)
axs[-1].set_title("Labels")
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.colors import LinearSegmentedColormap
from matplotlib import cm
import numpy as np
original_colormap = [ [ 0, 0, 0, 0 ], [ 0, 224, 249, 255 ], [ 0, 249, 50, 255 ], [ 174, 249, 0, 255 ], [ 249, 100, 0, 255 ], [ 249, 0, 125, 255 ], [ 149, 0, 249, 255 ], [ 0, 0, 206, 255 ], [ 0, 185, 206, 255 ], [ 0, 206, 41, 255 ], [ 143, 206, 0, 255 ], [ 206, 82, 0, 255 ], [ 206, 0, 103, 255 ], [ 124, 0, 206, 255 ], [ 0, 0, 162, 255 ], [ 0, 145, 162, 255 ], [ 0, 162, 32, 255 ], [ 114, 162, 0, 255 ], [ 162, 65, 0, 255 ], [ 162, 0, 81, 255 ], [ 97, 0, 162, 255 ], [ 0, 0, 119, 255 ], [ 0, 107, 119, 255 ], [ 0, 119, 23, 255 ], [ 83, 119, 0, 255 ], [ 119, 47, 0, 255 ], [ 119, 0, 59, 255 ], [ 71, 0, 119, 255 ], [ 100, 100
145, 145, 162, 255 ], [ 145, 160, 162, 255 ], [ 145, 162, 149, 255 ], [ 157, 162, 145, 255 ], [ 162, 152, 145, 255 ], [ 162, 145, 153, 255 ], [ 155, 145, 162, 255 ], [ 107, 107, 119, 255 ], [ 107, 118, 119, 255 ], [ 107, 119, 109, 255 ], [ 115, 119, 107, 255 ], [ 119, 112, 107, 255 ], [ 119, 107, 113, 255 ], [ 114, 107, 119, 255 ], [ 0, 0, 249, 255 ], [ 0, 224, 249, 255 ], [ 0, 249, 50, 255 ], [ 174, 249, 0, 255 ], [ 249, 100, 0, 255 ], [ 249, 0, 125, 255 ], [ 149, 0, 249, 255 ], [ 0, 0, 206, 255 ], [ 0, 185, 206, 255 ], [ 0, 206, 41, 255 ], [ 143, 206, 0, 255 ], [ 206, 82, 0, 255 ], [ 206, 0, 103, 255 ], [ 124, 0, 206, 255 ], [ 0, 0, 162, 255 ], [ 0, 145, 162, 255 ], [ 0, 162, 32, 255 ], [ 114, 162, 0, 255 ], [ 162, 65, 0, 255 ], [ 162, 0, 81, 255 ], [ 97, 0, 162, 255 ], [ 0, 0, 119, 255 ], [ 0, 107, 119, 255 ], [ 0, 119, 23, 255 ], [ 83, 119, 0, 255 ], [ 119, 47, 0, 255 ], [ 119, 0, 59, 255 ], [ 71, 0, 119, 255 ], [ 100, 100, 249, 255 ], [ 100, 234, 249, 255 ], [ 100, 249, 129, 255 ], [ 0, 249, 50, 255 ] ]
colormap = np.array(original_colormap)/255.
cmap = LinearSegmentedColormap.from_list('my_cmap', colors=colormap)

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[-1].imshow([[i] for i in list(range(n_labels))], **label_plot_args)
axs[-1].set_yticks(label_index)
axs[-1].set_yticklabels(label_names)
axs[-1].yaxis.tick_right()
axs[-1].get_xaxis().set_visible(False)
axs[-1].set_title("Labels")

batch = next(tr_dl)
idx = 3
axs[0].imshow(batch['data'][idx].permute(1, 2, 0).cpu().numpy())
axs[0].imshow(batch['target'][0][idx].permute(1, 2, 0).cpu().numpy(), vmin=0, vmax=255, alpha=.4, cmap=cmap, interpolation='nearest')

plt.show()

# %%
batch = next(tr_dl)
idx = 3
plt.imshow(batch['data'][idx].permute(1, 2, 0).cpu().numpy())
plt.imshow(batch['target'][0][idx].permute(1, 2, 0).cpu().numpy(), vmin=0, vmax=255, alpha=.3, cmap=cmap, interpolation='nearest')
plt.show()

# %%
batch = next(tr_dl)
plt.imshow(batch['data'][idx].permute(1, 2, 0).cpu().numpy())
plt.show()
for i in batch['target']:
    plt.imshow(i[idx].permute(1, 2, 0).cpu().numpy(), vmin=0, vmax=255, cmap=cmap, interpolation='nearest')
    plt.show()

# %%
batch = next(tr_dl)
for i in batch['data'].permute(0, 2, 3, 1):
    plt.imshow(i.cpu().numpy())
    plt.show()

# %%
1/0

# %%
next(tr_dl)

# %%
1/0

# %%
tr_dl.stop()

# %%
val_dl.stop()
